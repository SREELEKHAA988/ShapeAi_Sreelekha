# %%
 
from keras.datasets import mnist
data = mnist.load_data()
 
((X_train,Y_train),(X_test,Y_test))=data
 
 
X_train=X_train.reshape((X_train.shape[0],28*28)).astype('float32')
X_test=X_test.reshape((X_test.shape[0],28*28)).astype('float32')
X_train=X_train/255
X_test=X_test/255
from keras.utils import np_utils
print(Y_test.shape)
Y_train=np_utils.to_categorical(Y_train)
Y_test=np_utils.to_categorical(Y_test)
num_classes=Y_test.shape[1]
 
print(Y_test.shape)
from keras.models import Sequential
from keras.layers import Dense
 
model=Sequential ()
model.add(Dense(32,input_dim=28*28, activation='relu'))
model.add(Dense(64, activation='relu'))
 
model.add(Dense(10, activation='softmax'))
 
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
model.fit(X_train,Y_train,epochs=10,batch_size=100)
scores=model.evaluate(X_test,Y_test)
print (scores)
# Out:
# (10000,)
# (10000, 10)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.7808 - accuracy: 0.7752
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2089 - accuracy: 0.9399
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1569 - accuracy: 0.9544
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1297 - accuracy: 0.9622
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1114 - accuracy: 0.9674
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0974 - accuracy: 0.9711
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0885 - accuracy: 0.9736
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0772 - accuracy: 0.9759
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0731 - accuracy: 0.9784
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0634 - accuracy: 0.9805
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1187 - accuracy: 0.9661
# [0.11872624605894089, 0.9660999774932861]
